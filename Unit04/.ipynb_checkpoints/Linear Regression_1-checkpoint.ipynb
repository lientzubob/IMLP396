# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
# Out:
# [0.52369154 1.03800107 0.44680345 1.51497392 0.93292929 1.27027047
#  1.91053591 2.37463183 2.05005334 2.26587811 1.96248782 1.78217703
#  2.11315375 3.14761499 1.14093259 3.21365534 2.8293726  2.31541887
#  1.70869734 2.96266961 3.67112046 3.16608207 3.18873177 2.42984909
#  3.72821286 5.04214402 4.75702176 3.11080172 5.54344352 3.62928726
#  3.99178401 4.67837396 5.19816965 4.38848935 4.73703774 5.60227082
#  5.61952928 5.80619858 6.26248182 5.90619867 5.4124647  6.48270252
#  6.408989   5.17489387 6.29573893 7.47195267 6.46987272 6.75918108
#  7.62396104 7.48793644]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression()

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape)
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
print(Y)
# Out:
# [0.61357054 0.74652592 0.8794813  1.01243669 1.14539207 1.27834745
#  1.41130283 1.54425822 1.6772136  1.81016898 1.94312436 2.07607974
#  2.20903513 2.34199051 2.47494589 2.60790127 2.74085666 2.87381204
#  3.00676742 3.1397228  3.27267818 3.40563357 3.53858895 3.67154433
#  3.80449971 3.9374551  4.07041048 4.20336586 4.33632124 4.46927662
#  4.60223201 4.73518739 4.86814277 5.00109815 5.13405354 5.26700892
#  5.3999643  5.53291968 5.66587506 5.79883045 5.93178583 6.06474121
#  6.19769659 6.33065197 6.46360736 6.59656274 6.72951812 6.8624735
#  6.99542889 7.12838427]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.37134887928334515

# %%
#Y=WX+b
W=regr.coef_#斜率
W
# Out:
# array([1.30296275])

# %%
b=regr.intercept_ #截距
b
# Out:
# 0.6135705398988431

# %%
Y
# Out:
# array([0.61357054, 0.74652592, 0.8794813 , 1.01243669, 1.14539207,
#        1.27834745, 1.41130283, 1.54425822, 1.6772136 , 1.81016898,
#        1.94312436, 2.07607974, 2.20903513, 2.34199051, 2.47494589,
#        2.60790127, 2.74085666, 2.87381204, 3.00676742, 3.1397228 ,
#        3.27267818, 3.40563357, 3.53858895, 3.67154433, 3.80449971,
#        3.9374551 , 4.07041048, 4.20336586, 4.33632124, 4.46927662,
#        4.60223201, 4.73518739, 4.86814277, 5.00109815, 5.13405354,
#        5.26700892, 5.3999643 , 5.53291968, 5.66587506, 5.79883045,
#        5.93178583, 6.06474121, 6.19769659, 6.33065197, 6.46360736,
#        6.59656274, 6.72951812, 6.8624735 , 6.99542889, 7.12838427])

# %%
#可以將新的x資料帶入算出結果
W*3+b
# Out:
# array([4.52245878])

# %%
y
# Out:
# array([0.52369154, 1.03800107, 0.44680345, 1.51497392, 0.93292929,
#        1.27027047, 1.91053591, 2.37463183, 2.05005334, 2.26587811,
#        1.96248782, 1.78217703, 2.11315375, 3.14761499, 1.14093259,
#        3.21365534, 2.8293726 , 2.31541887, 1.70869734, 2.96266961,
#        3.67112046, 3.16608207, 3.18873177, 2.42984909, 3.72821286,
#        5.04214402, 4.75702176, 3.11080172, 5.54344352, 3.62928726,
#        3.99178401, 4.67837396, 5.19816965, 4.38848935, 4.73703774,
#        5.60227082, 5.61952928, 5.80619858, 6.26248182, 5.90619867,
#        5.4124647 , 6.48270252, 6.408989  , 5.17489387, 6.29573893,
#        7.47195267, 6.46987272, 6.75918108, 7.62396104, 7.48793644])
