# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2.  線性迴歸訓練資料、測試資料
#
# 80%  training data, 20%  testing data ==> 先利用此來驗證各種模型(演算法)的好壞及調好到最佳參數
# 之後可以利用由這個80%的訓練資料所得的模型後,拿100%資料re-train模型以得到最佳模型 (此model會更佳fit data)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = np.linspace(0, 5, 50)
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)
print(x_train)
# Out:
# [4.08163265 1.73469388 1.83673469 0.         2.75510204 3.36734694
#  3.67346939 4.28571429 1.02040816 0.30612245 4.18367347 1.32653061
#  4.69387755 0.20408163 3.87755102 3.97959184 0.51020408 4.3877551
#  3.7755102  3.06122449 0.6122449  2.95918367 1.63265306 1.93877551
#  5.         4.48979592 2.14285714 3.26530612 3.46938776 0.71428571
#  2.24489796 1.12244898 2.04081633 0.91836735 4.89795918 2.85714286
#  3.16326531 1.53061224 2.65306122 3.57142857]

# %%
y
# Out:
# array([0.85227583, 1.29974071, 0.52621764, 1.84813091, 1.07973276,
#        0.5442593 , 2.77904812, 0.48350919, 1.69740021, 1.64648415,
#        1.82047848, 1.1770406 , 2.95718683, 2.30751972, 2.58194678,
#        2.58572593, 1.61124917, 3.11890637, 3.13300485, 4.2086462 ,
#        3.26170944, 3.36529342, 3.12343584, 3.87022832, 3.35496847,
#        3.84305685, 4.9806854 , 4.41648205, 5.08730326, 3.45033172,
#        3.61401835, 4.88803385, 3.43670693, 5.28816089, 4.45376663,
#        5.92128103, 4.85404202, 5.36571296, 5.72618756, 6.69728347,
#        6.77777258, 5.72426553, 6.80222203, 5.77849096, 5.6597398 ,
#        6.85545602, 6.65077866, 6.504483  , 6.92002604, 5.75368864])

# %%
plt.scatter(x_train, y_train)

# %% [markdown]
# #### 用訓練資料來 fit 函數
#
# 記得現在我們只用 80% 的資料去訓練。

# %%
regr = LinearRegression()
X_train = x_train.reshape(-1,1)
regr.fit(X_train,y_train)
print('Coefficients: ', regr.coef_)
print('interception: ', regr.intercept_)
# Out:
# Coefficients:  [1.25741731]
# interception:  0.6377313238360518

# %%
Y_train = regr.predict(X_train)

# %%
mse = np.sum((Y_train-y_train)**2) / len(y_train)
print(mse)
# Out:
# 0.4772877561881952

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, Y_train, 'r')

# %% [markdown]
# #### test with test data

# %%
X_test = x_test.reshape(-1,1)
Y_test = regr.predict(X_test)

print(Y_test)
# Out:
# [2.17742599 2.43404177 1.15096288 1.66419444 6.41158633 0.76603921
#  3.84542855 3.71712066 6.66820211 3.58881277]

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+b$$

# %%
#Y=WX+b
W=regr.coef_
b=regr.intercept_
W*X_test+b
# Out:
# array([[2.17742599],
#        [2.43404177],
#        [1.15096288],
#        [1.66419444],
#        [6.41158633],
#        [0.76603921],
#        [3.84542855],
#        [3.71712066],
#        [6.66820211],
#        [3.58881277]])

# %%
mse = np.sum((Y_test-y_test)**2) / len(y_test)
print(mse)
# Out:
# 0.13550952890944967

# %%
title='f(x)=1.2x+0.8'+',mse:'+str(round(mse,2))
plt.title(title)
plt.xlabel('x')
plt.ylabel('y')
#plt.grid(True)
plt.scatter(x_test, y_test,alpha=0.8,label='Ground Truth')
plt.scatter(x_test, Y_test, c='r', alpha=0.8,label='Predict')
plt.legend()
